# %%
Introduction to python fundamentals

# %%
a=2
b=2
c=a+b
print(c)
# Out:
# 4

# %%
firstname='charitha'
print(firstname)
# Out:
# charitha

# %%
1name="charitha" #it will give syntax error as it is starting with number
print(1name)
# Out:
#   Cell In[3], line 1
#     1name="charitha" #it will give syntax error as it is starting with number
#     ^
# SyntaxError: invalid decimal literal

# %%
name1="Charitha"
print(name1)
# Out:
# Charitha

# %%
test@="swathi"  # it gives syntax error it has special characters included
print(test@)
# Out:
#   Cell In[5], line 2
#     print(test@)
#                ^
# SyntaxError: invalid syntax

# %%
name1='bavana'  #using single quote
print(name1)
# Out:
# bavana

# %%
name2="chnadra"  #using double quote
print(name2)
# Out:
# chnadra

# %%
type(name1)
# Out:
# str

# %%
type(name2)
# Out:
# str

# %%
fullname='murali prasad'
print(fullname)
# Out:
# murali prasad

# %%
#req: how to correct the format
print(fullname.title())
# Out:
# Murali Prasad

# %%
#req: I want the entire name in capital letters
print(fullname.upper())
# Out:
# MURALI PRASAD

# %%
#req: I want the entire name in smallcase letters
print(fullname.lower())
# Out:
# murali prasad
