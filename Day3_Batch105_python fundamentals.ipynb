# %%
introduction to f string:

# %%
firstname='saurabh'
lastname='jaiswal'

# %%
#message=f" custom {place_holder_1} {place_holder_2} {place_holder_n}

fullname=f"{firstname} {lastname}"
print(fullname)
# Out:
# saurabh jaiswal

# %%
print(fullname.title())
# Out:
# Saurabh Jaiswal

# %%
message =f"Keep up the good work, {fullname.title()}"
print(message)
# Out:
# Keep up the good work, Saurabh Jaiswal

# %%
introduction to whitespaces:

# %%
print("Fav_prog:PythonJavaC++swiftjavascript")
# Out:
# Fav_prog:PythonJavaC++swiftjavascript

# %%
print("Fav_prog:\nPython\nJava\nC++\nswift\njavascript")
# Out:
# Fav_prog:
# Python
# Java
# C++
# swift
# javascript

# %%
print("Fav_prog:\n\tPython\n\tJava\n\tC++\n\tswift\n\tjavascript")
# Out:
# Fav_prog:
# 	Python
# 	Java
# 	C++
# 	swift
# 	javascript

# %%
eliminating whitespaces:

# %%
name='  python'
print(name)
# Out:
#   python

# %%
name3="python   "
print(name3)

# %%
name4="python"
print(name4)
# Out:
# python

# %%
name.lstrip() #left stripping
# Out:
# 'python'

# %%
name3.rstrip() #right strip
# Out:
# 'python'
