# %%
introduction to list datatypes:
def: list is a collection of items declared in a particular order 
classified : it is classified as a mutable datatype

how to declare the list datatype----------->[]

# %%
students=['Akihila','dinesh','david','divya','Karthik']
print(students)
# Out:
# ['Akihila', 'dinesh', 'david', 'divya', 'Karthik']

# %%
introduction to indexing: 0,1,2,3,4......

# %%
# i want to access dinesh name in the output?
list(students[1])
# Out:
# ['d', 'i', 'n', 'e', 's', 'h']

# %%
#i want to get David name in the output
print(students[2])
# Out:
# david

# %%
how to add new elements in the list?
how to modify the elements in the list?
how to delete the elements in the list?

# %%
# i want to add kiran in the list
students.append('kiran')
print(students)
# Out:
# ['Akihila', 'dinesh', 'david', 'divya', 'Karthik', 'kiran']

# %%
# i want to add hamza in the above list?
students.append('hamza')
print(students)
# Out:
# ['Akihila', 'dinesh', 'david', 'divya', 'Karthik', 'kiran', 'hamza', 'hamza']

# %%
# i want to add masooda at 2nd index?
students.insert(2,'masooda')
print(students)
# Out:
# ['Akihila', 'dinesh', 'masooda', 'david', 'divya', 'Karthik', 'kiran', 'hamza', 'hamza']

# %%
# i want to modify dinesh name to sana
students[1]="masooda"
print(students)
# Out:
# ['Akihila', 'masooda', 'masooda', 'david', 'divya', 'Karthik', 'kiran', 'hamza', 'hamza']

# %%
# i want to modify dinesh name to sana
students[1]="sana"
print(students)
# Out:
# ['Akihila', 'sana', 'masooda', 'david', 'divya', 'Karthik', 'kiran', 'hamza', 'hamza']

# %%
# i want to delete David name
del students[3]
print(students)
# Out:
# ['Akihila', 'sana', 'masooda', 'divya', 'Karthik', 'kiran', 'hamza', 'hamza']
